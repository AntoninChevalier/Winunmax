# %%
# %load_ext autoreload
# %autoreload 2
import importlib
import pandas as pd
from IPython.display import display
import seaborn as sns
import matplotlib.pyplot as plt
import sys
sys.path.append("../src/")
import nettoyage
importlib.reload(nettoyage)
# Out:
# <module 'nettoyage' from 'c:\\Users\\anton\\Downloads\\A3\\analyse données\\Winunmax\\notebooks\\../src\\nettoyage.py'>

# %%
#Initialisation des dataframes à partir des .csv bruts

df_clubs = pd.read_csv("../data/brute/clubs_fr.csv")
df_clubs.info()
display(df_clubs.head(3))
df_composition_equipes = pd.read_csv("../data/brute/game_lineups.csv")
df_composition_equipes.info()
display(df_composition_equipes.head(3))
df_detail_matchs = pd.read_csv("../data/brute/game_events.csv")
df_detail_matchs.info()
display(df_detail_matchs.head(3))
df_cartons_joueurs = pd.read_csv("../data/brute/player_appearance.csv")
df_cartons_joueurs.info()
display(df_cartons_joueurs.head(3))
df_valeur_joueurs = pd.read_csv("../data/brute/player_valuation_before_season.csv")
df_valeur_joueurs.info()
display(df_valeur_joueurs.head(3))
df_resultat_matchs = pd.read_csv("../data/brute/matchs_2013_2022.csv")
df_resultat_matchs.info()
display(df_resultat_matchs.head(3))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   club_id                  35 non-null     int64
#  1   club_code                35 non-null     object
#  2   name                     35 non-null     object
#  3   domestic_competition_id  35 non-null     object
#  4   squad_size               35 non-null     int64
#  5   average_age              35 non-null     float64
#  6   foreigners_number        35 non-null     int64
#  7   foreigners_percentage    35 non-null     float64
#  8   national_team_players    35 non-null     int64
#  9   stadium_name             35 non-null     object
#  10  stadium_seats            35 non-null     int64
#  11  net_transfer_record      35 non-null     object
#  12  coach_name               0 non-null      float64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 3.7+ KB
# ...

# %%
#On remarque grâce aux .info() ci-dessus que les dates ne sont pas de type datetime

df_valeur_joueurs["date"] = pd.to_datetime(df_valeur_joueurs["date"])
df_composition_equipes["date"] = pd.to_datetime(df_composition_equipes["date"])
df_resultat_matchs["date"] = pd.to_datetime(df_resultat_matchs["date"])
df_cartons_joueurs["date"] = pd.to_datetime(df_cartons_joueurs["date"])
df_detail_matchs["date"] = pd.to_datetime(df_detail_matchs["date"])

# %%
#Test de la corrélation sur le dataframe de match initial

nettoyage.afficher_matrice_correlation(df_resultat_matchs)

#Aucune corrélation très proche de 1, donc une analyse plus approfondie est nécessaire

# %%
#Calcul de la valorisation par équipe, ici seulement les 11 de départs

df_valeur_equipes = nettoyage.calcul_market_value_sans_remplacant(df_composition_equipes,df_valeur_joueurs)

display(df_valeur_equipes.head(5))
display(df_valeur_equipes["team_market_value"].median())
# Out:
#    game_id  club_id  team_market_value
# 0  2330825      750         14400000.0
# 1  2330825      969         12800000.0
# 2  2330826      244         63500000.0
# 3  2330826     1423         10450000.0
# 4  2330827      583         39000000.0
# np.float64(22000000.0)

# %%
#Vérification de la valorisation des équipes en temps réel : CORRECT
print("Vérification manuelle correcte !")


print(df_valeur_equipes[(df_valeur_equipes["game_id"] == 2330825) & (df_valeur_equipes["club_id"] == 750)])

display(df_composition_equipes[(df_composition_equipes["game_id"]==2330825) & (df_composition_equipes["club_id"]==750) & (df_composition_equipes["type"]=="starting_lineup")].head(37))

tab_player_id = [5614,17693,24105,28987,52027,52893,56806,78917,102744,127048,271390]
df_valeur_joueurs_test = df_valeur_joueurs.copy()
df_valeur_joueurs_test["date"] = pd.to_datetime(df_valeur_joueurs_test["date"]) 
df_valeur_joueurs_test = df_valeur_joueurs_test.sort_values(by="date",ascending=False)
display(df_valeur_joueurs_test[(df_valeur_joueurs_test["player_id"].isin(tab_player_id) & (df_valeur_joueurs_test["date"]<="2013-08-24"))].drop_duplicates(subset="player_id",keep="first").head(37))
# Out:
# Vérification manuelle correcte !
#    game_id  club_id  team_market_value
# 0  2330825      750         14400000.0
#     Unnamed: 0                   game_lineups_id       date  game_id  \
# 2        34477  46552e9ff9777efa2e2d0df3a8147d87 2013-08-24  2330825
# 4        34479  d6592bfd4c2c2f06a388086f8b0b714e 2013-08-24  2330825
# 7        34482  0a4efcc33b613abc0d2c7a0f4c9e67e3 2013-08-24  2330825
# 8        34483  206c4ff4e9dc78a897451abbc164c224 2013-08-24  2330825
# 11       34486  11170b900fee8d0916a8faf8e0f45882 2013-08-24  2330825
# 12       34487  d766301c3718f54460755e007a187ab1 2013-08-24  2330825
# 13       34488  1575a82a08face2c3c3fcd72c826798f 2013-08-24  2330825
# 17       34492  22086692f3dd8a2ccbdd8f4318489045 2013-08-24  2330825
# 18       34493  43690e264b3ccf4eb8cce88e311d2b4a 2013-08-24  2330825
# 24       34499  ab777c2e330f1dd6ac9ada44d97a6899 2013-08-24  2330825
# 35       34510  5251a928e2d879e215ede6cfbe2d7c20 2013-08-24  2330825
#
# ...

# %%
#Vérification si chaque équipe joue le même nombre de match : NON ---> on doit donc calculer le winrate

verification_match_domicile = df_resultat_matchs["home_club_id"].value_counts()
verification_match_exterieur = df_resultat_matchs["away_club_id"].value_counts()
verification_nb_total_match = verification_match_domicile.add(verification_match_exterieur,fill_value=0).astype(int)
verification_nb_total_match = verification_nb_total_match.reset_index()
verification_nb_total_match.head(5)
# Out:
#    index  count
# 0     40    370
# 1    162    370
# 2    244    408
# 3    273    408
# 4    290     38

# %%
#Calcul winrate globale par équipe

winrate_global = nettoyage.calculer_winrate_global(df_resultat_matchs)
display(winrate_global.head(50))
# Out:
#     club_id  winrate_global
# 0        40        0.493243
# 1       162        0.652703
# 2       244        0.622549
# 3       273        0.530637
# 4       290        0.355263
# 5       347        0.369266
# 6       415        0.411145
# 7       417        0.550245
# 8       583        0.799754
# 9       595        0.439474
# 10      618        0.532520
# 11      667        0.465438
# 12      750        0.401316
# 13      826        0.552632
# 14      855        0.418860
# 15      969        0.482843
# 16      995        0.460811
# 17     1041        0.628993
# 18     1082        0.585784
# 19     1095        0.307895
# 20     1147        0.311404
# 21     1158        0.437500
# 22     1159        0.361842
# 23     1160        0.403846
# 24     1162        0.402632
# 25     1416        0.389423
# 26     1420        0.413265
# 27     1421        0.466867
# 28     1423        0.381579
# 29     2969        0.358333
# 30     3524        0.453947
# 31     3558        0.381579
# ...

# %%
#Vérification manuelle du winrate global : CORRECTE

display(df_resultat_matchs[df_resultat_matchs["home_club_id"]==290])
display(df_resultat_matchs[df_resultat_matchs["away_club_id"]==290])
# Out:
#       Unnamed: 0  game_id  season         round       date  home_club_id  \
# 438         6195  3840027    2022   8. Matchday 2022-09-16           290
# 463         6566  3840079    2022  13. Matchday 2022-10-30           290
# 706         9981  3840150    2022  20. Matchday 2023-01-29           290
# 965        13803  3840189    2022  24. Matchday 2023-02-17           290
# 993        14127  3840110    2022  16. Matchday 2022-12-28           290
# 1014       14373  3839841    2022   4. Matchday 2022-08-27           290
# 1224       17586  3840446    2022  38. Matchday 2023-06-03           290
# 1262       18122  3840040    2022   9. Matchday 2022-10-02           290
# 1453       21396  3840059    2022  11. Matchday 2022-10-16           290
# 1463       21406  3840277    2022  32. Matchday 2023-04-22           290
# 1733       28273  3840246    2022  29. Matchday 2023-04-01           290
# 1951       30942  3840266    2022  31. Matchday 2023-04-16           290
# ...

# %%
#Calcul Winrate entre A et B

# %%
#TODO choisir si on détermine la valorisation d’un match, d’un club à l’annnée N, à la valorisation moyenne du club ?
#TODO peut-être on peut faire du encodage one-hot des variables qualitatives ? ou peut-être en extraire des variables quantitatives (exemple nul mais explicatif, calculer la moyenne des victoires à domicile par arbitre, si c’est proche de 1, ça veut dire qu’il favorise les victoires à domicile etc...)

# %%
df_test = df_resultat_matchs[df_resultat_matchs["game_id"]==3839781].copy()
df_testt = df_valeur_equipes[df_valeur_equipes["game_id"]==3839781].copy()
df_testtt = df_composition_equipes[df_composition_equipes["game_id"]==3839781].copy()
df_testtt.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, game_lineups_id, date, game_id, player_id, club_id, player_name, type, position, number, team_captain]
# Index: []

# %%
#Création d’un dataframe centralisé qui comporte plus d’information que df_resultat_matchs

df_dataset_final = df_resultat_matchs.copy()
#Garder les colonnes qui nous intéressent
df_dataset_final = df_dataset_final[["home_club_name","away_club_name","game_id","date","season","home_club_id","away_club_id","home_club_position","away_club_position","results"]]
#Ajout de la différence de classement
df_dataset_final["difference classement"] = df_dataset_final["home_club_position"]-df_dataset_final["away_club_position"]
#Ajout ratio valorisation home par away
df_dataset_final = nettoyage.calcul_difference_valorisation(df_dataset_final,df_composition_equipes,df_valeur_joueurs)
df_dataset_final = nettoyage.calcul_ratio_valorisation(df_dataset_final,df_composition_equipes,df_valeur_joueurs)
df_dataset_final = nettoyage.calcul_log_ratio_valorisation(df_dataset_final,df_composition_equipes,df_valeur_joueurs)
#Ajout winrate
nb_annes = 1
df_dataset_final = nettoyage.calcul_winrate_historique(df_dataset_final,nb_annes)
df_dataset_final["difference winrate "+str(nb_annes)+" ans"] = df_dataset_final["winrate_home "+str(nb_annes)+" ans"]-df_dataset_final["winrate_away "+str(nb_annes)+" ans"]
nb_annes = 3
df_dataset_final = nettoyage.calcul_winrate_historique(df_dataset_final,nb_annes)
df_dataset_final["difference winrate "+str(nb_annes)+" ans"] = df_dataset_final["winrate_home "+str(nb_annes)+" ans"]-df_dataset_final["winrate_away "+str(nb_annes)+" ans"]
#Ajout winrate confrontation
nb_annes = 1
df_dataset_final = nettoyage.ajout_winrate_confrontation_directe(df_dataset_final,nb_annes)
nb_annes = 3
df_dataset_final = nettoyage.ajout_winrate_confrontation_directe(df_dataset_final,nb_annes)
#Ajout classement moyen des dernières années
nb_annes = 1
df_dataset_final = nettoyage.ajout_classement_moyen_historique(df_dataset_final,nb_annes)
df_dataset_final["difference classement moyen "+str(nb_annes)+" ans"] = df_dataset_final["pos_moy_home_"+str(nb_annes)+"_ans"]-df_dataset_final["pos_moy_away_"+str(nb_annes)+"_ans"]
nb_annes = 3
df_dataset_final = nettoyage.ajout_classement_moyen_historique(df_dataset_final,nb_annes)
df_dataset_final["difference classement moyen "+str(nb_annes)+" ans"] = df_dataset_final["pos_moy_home_"+str(nb_annes)+"_ans"]-df_dataset_final["pos_moy_away_"+str(nb_annes)+"_ans"]



display(df_dataset_final.tail(3))
# Out:
#                                     home_club_name  \
# 4075                        Toulouse Football Club
# 4076  Association sportive de Monaco Football Club
# 4077                         FC Girondins Bordeaux
#
#                         away_club_name  game_id       date  season  \
# 4075  Racing Club de Strasbourg Alsace  3047720 2019-01-13    2018
# 4076  Racing Club de Strasbourg Alsace  3199559 2020-01-25    2019
# 4077                 Stade brestois 29  3394685 2020-12-06    2020
#
#       home_club_id  away_club_id  home_club_position  away_club_position  \
# 4075           415           667                14.0                 8.0
# 4076           162           667                13.0                 8.0
# 4077            40          3911                10.0                12.0
#
#       results  ...  winrate_away 3 ans  difference winrate 3 ans  \
# 4075       -1  ...            0.381579                  0.026316
# ...

# %%
#Vérification manuelle winrate confrontation => CORRECT
display(df_dataset_final[(df_dataset_final["season"]==2018) & ((df_dataset_final["home_club_id"]==415) & (df_dataset_final["away_club_id"]==667))])
df_test = df_dataset_final[(df_dataset_final["season"]==2017) & (((df_dataset_final["home_club_id"]==415) & (df_dataset_final["away_club_id"]==667))|(df_dataset_final["home_club_id"]==667) & (df_dataset_final["away_club_id"]==415))].copy()
df_test.head(20)
# Out:
#               home_club_name                    away_club_name  game_id  \
# 4075  Toulouse Football Club  Racing Club de Strasbourg Alsace  3047720
#
#            date  season  home_club_id  away_club_id  home_club_position  \
# 4075 2019-01-13    2018           415           667                14.0
#
#       away_club_position  results  ...  Difference value home et away  \
# 4075                 8.0       -1  ...                    -15500000.0
#
#       Ratio value home par away  LOG Ratio value home par away  \
# 4075                   0.597403                      -0.515164
#
#       winrate_home 1 ans  winrate_away 1 ans  difference winrate 1 ans  \
# 4075            0.368421            0.381579                 -0.013158
#
#       winrate_home 3 ans  winrate_away 3 ans  difference winrate 3 ans  \
# 4075            0.407895            0.381579                  0.026316
#
#       winrate_confrontation_home 1 ans
# 4075                              0.25
#
# [1 rows x 21 columns]
# ...

# %%
#Peut être judicieux de retire du dataframe traités les lignes de 2012
print(len(df_dataset_final[(df_dataset_final["pos_moy_home_1_ans"]==20)]))
print(len(df_dataset_final[(df_dataset_final["pos_moy_home_1_ans"]==20) & (df_dataset_final["season"]!=2012)]))
display(df_dataset_final[(df_dataset_final["pos_moy_home_1_ans"]==20) & (df_dataset_final["season"]!=2012)].head(5))

print(len(df_dataset_final[(df_dataset_final["winrate_home 1 ans"]==0.35)]))
print(len(df_dataset_final[(df_dataset_final["winrate_home 1 ans"]==0.35) & (df_dataset_final["season"]!=2012)]))
# Out:
# 864
# 484
#                                   home_club_name  \
# 11  Association sportive de Monaco Football Club
# 15                           Racing Club de Lens
# 18                           Racing Club de Lens
# 33                                    Angers SCO
# 39                                     Dijon FCO
#
#                                    away_club_name  game_id       date  season  \
# 11                                    EA Guingamp  2331162 2014-05-07    2013
# 15  Lille Olympique Sporting Club Lille Métropole  2482268 2014-12-07    2014
# 18                    Stade Rennais Football Club  2482373 2015-02-28    2014
# 33                 Montpellier Hérault Sport Club  2609730 2016-02-20    2015
# 39                             Olympique Lyonnais  2701616 2016-08-27    2016
#
#     home_club_id  away_club_id  home_club_position  away_club_position  \
# 11           162           855                 2.0                16.0
# ...

# %%
df_dataset_final_affichage_cor = df_dataset_final.copy().drop(columns=["game_id","season","home_club_id","away_club_id"])
nettoyage.afficher_matrice_correlation(df_dataset_final_affichage_cor)

# %%
df_dataset_final.to_csv("../data/preparee/dataframe_traite.csv", index=False)
